# %%
from krakenpairs import *
import requests
pairs = list(get_pairs_kraken())

print(len(pairs))
print(pairs)

print(full_request_string)

count = str(2)
request_string = "https://api.kraken.com/0/public/Depth?pair="

for pair in pairs:
        full_request_string = request_string + pair[0] + "&count=" + count
        resp = resp = requests.get(full_request_string)
        json_dict = dict(resp.json())
        print(pair)
        print(resp.json())
        print(json_dict['result'])
    
def get_best_k_asks_kraken(json_dict):
    pass
# Out:
# 400
# ...
